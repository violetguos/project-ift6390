# %%
import scipy.io.wavfile as wavfile
from scipy.io.wavfile import read
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
import glob, os
data=[]
os.chdir("C:\Users\jonat\Documents\School\ML\Untitled Folder\RawData")
for file in glob.glob("*.wav"):
    data.append(file)
print(data)
# Out:
#   File "<ipython-input-35-74a03890c6c0>", line 3
#     os.chdir("C:\Users\jonat\Documents\School\ML\Untitled\ Folder\RawData")
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
file_name = "1_0.wav"
# file_name = file_name[:-4]
print(file_name)
sr_value, x_value = read(file_name)
f, t, Sxx= signal.spectrogram(x_value,sr_value)
spect_dict = {}
spect_dict['f'] = f
spect_dict['t'] = t
spect_dict['Sxx'] = Sxx
# pickle.dump( spec_dict, open(file_name+'.pickle', "wb" ) )
# Out:
# 1_0.wav

# %%
# Load the data and calculate the time of each sample

samplerate, data = wavfile.read('1_0.wav')

times = np.arange(len(data))/float(samplerate)



# Make the plot

# You can tweak the figsize (width, height) in inches

plt.figure(figsize=(30, 4))

# plt.fill_between(times, data[:,0], data[:,1], color='k') 
plt.fill_between(times, data)

plt.xlim(times[0], times[-1])

plt.xlabel('time (s)')

plt.ylabel('amplitude')

# You can set the format by changing the extension

# like .pdf, .svg, .eps

# plt.savefig('plot.png', dpi=100)

plt.show()

# %%
l='1_0.wav'
spectrum, specs, t, i = plt.specgram(x_value, NFFT=80, Fs=16000,  noverlap=40)
plt.ylim(0,8000)
plt.xlim(0.5,20)
plt.show()
print(spectrum)
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.75087658e-02
#   4.02665183e-03 1.33418824e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 5.04698223e-02
#   5.88815566e-02 1.75030800e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 5.77511062e-03
#   7.68973524e-02 5.93236551e-02]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.95014744e-02
#   4.44220421e-02 1.17379721e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.72474038e-02
#   1.90060535e-02 1.19867810e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 6.40698507e-06
#   6.27824273e-04 5.18180717e-04]]
